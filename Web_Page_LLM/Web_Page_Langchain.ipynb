# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate 
from dotenv import load_dotenv, find_dotenv 

load_dotenv(find_dotenv(), override = True)

# %%
llm = ChatOpenAI(model = "gpt-4o-mini", temperature = 0)

# %%
template = """
You are an expert frontend developer specializing in html, css, and JavaScript frontend code as well as all of their frontend libraries such 
as bootstrap. 


You will be given a complete html code file. This file is verified to be viewable and runnable in a user's browser. 
This means that the html code when viewed with the python function 'webbrowser.open('html_file')' displays the entire html code as well as any images, animated parts, JavaScript elements, etc. without any errors. 


Your job is to return the provided html code in a similar ERROR FREE state (viewable and runnable in a browser) but without elements of the webpage that may be distracting to an academic student user. 
RETURN ONLY THE HTML CODE in a way that it is able to be run in a browser. Again, the html code should run ERROR FREE and without elements of the web page that may be distracting to a student user. 

PROVIDED HTML CODE: 
----------------------------------------------------


{original_html_code}


"""

# %%
template_images_removed = """
You are an expert frontend developer specializing in html, css, and JavaScript frontend code as well as all of their frontend libraries such 
as bootstrap. 


You will be given a complete html code file. This file is verified to be viewable and runnable in a user's browser. 
This means that the html code when viewed with the python function 'webbrowser.open('html_file')' displays the entire html code as well as any images, animated parts, JavaScript elements, etc. without any errors. 


Your job is to return the provided html code in a similar ERROR FREE state (viewable and runnable in a browser) but without elements of the webpage such as images, animations, and pictures that may be distracting to an academic student user. 
RETURN ONLY THE HTML CODE in a way that it is able to be run in a browser. Again, the html code should run ERROR FREE and without elements of the web page, ONLY images, animations, and pictures, that may be distracting to a student user. 

PROVIDED HTML CODE: 
----------------------------------------------------


{original_html_code}


"""

# %%
prompt_template = ChatPromptTemplate.from_template(template = template)

html_editor_chain = prompt_template | llm

# %%
prompt_template_images_removed = ChatPromptTemplate.from_template(template = template_images_removed)

html_editor_chain_images_removed = prompt_template_images_removed | llm

# %%
from Web_Page_Download.web_page_download_using_subprocess import download_web_page

# %%
download_web_page(url = "https://www.selenium.dev")

# %%
with open("wget_web_page/www.selenium.dev/index.html", "r") as file: 
    html_original = file.read()

# %%
print(html_original)

# %%
with open("wget_web_page/www.selenium.dev/html_original.html", "w") as file_2: 
    file_2.write(html_original)

# %%
import webbrowser 

webbrowser.open("wget_web_page/www.selenium.dev/html_original.html")
webbrowser.open("wget_web_page/www.selenium.dev/index.html")

# %%
download_web_page(url = "https://www.apple.com")
# Out:
# --2024-10-31 08:55:15--  https://www.apple.com/
# Resolving www.apple.com (www.apple.com)... 104.99.49.26, 2600:1406:3a00:28b::1aca, 2600:1406:3a00:286::1aca
# Connecting to www.apple.com (www.apple.com)|104.99.49.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 190687 (186K) [text/html]
# Saving to: ‘./wget_web_page/www.apple.com/index.html’
#
#      0K .......... .......... .......... .......... .......... 26% 2.47M 0s
#     50K .......... .......... .......... .......... .......... 53% 3.38M 0s
#    100K .......... .......... .......... .......... .......... 80% 5.36M 0s
#    150K .......... .......... .......... ......               100% 66.0M=0.04s
#
# 2024-10-31 08:55:15 (4.14 MB/s) - ‘./wget_web_page/www.apple.com/index.html’ saved [190687/190687]
#
# Loading robots.txt; please ignore errors.
# --2024-10-31 08:55:15--  https://www.apple.com/robots.txt
# Reusing existing connection to www.apple.com:443.
# ...

# %%
with open("wget_web_page/www.apple.com/index.html", "r") as file: 
    html_original = file.read()
    
print(html_original)
# Out:
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en-US" lang="en-US" prefix="og: http://ogp.me/ns#" class="no-js" data-layout-name="mountains">
# <head>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <meta charset="utf-8" />
# <link rel="canonical" href="index.html" />
#
#
#
# ...

# %%
with open("wget_web_page/www.apple.com/html_original.html", "w") as file_2: 
    file_2.write(html_original)

# %%
webbrowser.open("wget_web_page/www.apple.com/html_original.html")
webbrowser.open("wget_web_page/www.apple.com/index.html")
# Out:
# True

# %%
output = html_editor_chain.invoke(input = {"original_html_code": html_original})

# %%
print(output.content)
# Out:
# ```html
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
#     <meta charset="utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1, viewport-fit=cover" />
#     <title>Apple</title>
#     <meta name="Description" content="Discover the innovative world of Apple and shop everything iPhone, iPad, Apple Watch, Mac, and Apple TV, plus explore accessories, entertainment, and expert device support." />
#     <link rel="stylesheet" type="text/css" href="api-www/global-elements/global-header/v1/assets/globalheader.css" />
#     <link rel="stylesheet" type="text/css" href="v/home/bu/built/styles/main.built.css" type="text/css" />
# </head>
# <body>
#
#     <main role="main">
#         <section class="homepage-section collection-module">
#             <div data-unit-id="macbook-pro-enhanced">
#                 <div class="module-content">
#                     <div class="unit-wrapper split-copy-wrapper theme-dark">
# ...

# %%
with open("wget_web_page/www.apple.com/html_edited.html", "w") as file_3: 
    file_3.write(output.content)

# %%
webbrowser.open("wget_web_page/www.apple.com/html_edited.html")
# Out:
# True

# %%
output_images_removed = html_editor_chain_images_removed.invoke(input = {"original_html_code": html_original})

# %%
with open("wget_web_page/www.apple.com/html_edited_images_removed.html", "w") as file_3: 
    file_3.write(output_images_removed.content)
    
webbrowser.open("wget_web_page/www.apple.com/html_edited_images_removed.html")
# Out:
# True

# %%
import subprocess

def download_web_page_new(url: str, output_dir: str = "wget_web_page"): 
    try:
        command = ["wget", "--no-proxy", "-p", "-k", "-U", "Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.8.1.6) Gecko/20070802 SeaMonkey/1.1.4", url, "-P", f"./{output_dir}/"]
        subprocess.run(command) 
        url_new = url.replace("https://", "")
        web_page_dir = f"./{output_dir}/{url_new}/index.html"
        return {"is_successful": True, "web_page_dir": web_page_dir}
    except Exception: 
        raise Exception

download_web_page_new(url = "https://www.amazon.com")
# Out:
# --2024-10-31 10:00:28--  https://www.amazon.com/
# Resolving www.amazon.com (www.amazon.com)... 23.195.146.115, 2600:9000:234b:4e00:7:49a5:5fd4:b121, 2600:9000:234b:2200:7:49a5:5fd4:b121, ...
# Connecting to www.amazon.com (www.amazon.com)|23.195.146.115|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘./wget_web_page/www.amazon.com/index.html’
#
#      0K .......... .......... .......... .......... .......... 2.22M
#     50K .......... .......... .......... .......... .......... 3.75M
#    100K .......... .......... .......... .......... .......... 3.94M
#    150K .......... .......... .......... .......... .......... 16.9M
#    200K ......                                                  328M=0.05s
#
# 2024-10-31 10:00:28 (4.01 MB/s) - ‘./wget_web_page/www.amazon.com/index.html’ saved [211346]
#
# Loading robots.txt; please ignore errors.
# --2024-10-31 10:00:28--  https://www.amazon.com/robots.txt
# ...

# %%
webbrowser.open(url = "wget_web_page/www.amazon.com/index.html")
# Out:
# True

# %%
download_web_page_new(url = "https://www.apple.com")
# Out:
# --2024-10-31 10:04:08--  https://www.apple.com/
# Resolving www.apple.com (www.apple.com)... 104.99.49.26, 2600:1406:3a00:286::1aca, 2600:1406:3a00:28d::1aca
# Connecting to www.apple.com (www.apple.com)|104.99.49.26|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 190687 (186K) [text/html]
# Saving to: ‘./wget_web_page/www.apple.com/index.html’
#
#      0K .......... .......... .......... .......... .......... 26% 2.55M 0s
#     50K .......... .......... .......... .......... .......... 53% 2.91M 0s
#    100K .......... .......... .......... .......... .......... 80% 11.1M 0s
#    150K .......... .......... .......... ......               100% 5.33M=0.05s
#
# 2024-10-31 10:04:08 (3.88 MB/s) - ‘./wget_web_page/www.apple.com/index.html’ saved [190687/190687]
#
# Loading robots.txt; please ignore errors.
# --2024-10-31 10:04:08--  https://www.apple.com/robots.txt
# Reusing existing connection to www.apple.com:443.
# ...

# %%
webbrowser.open("wget_web_page/www.apple.com/index.html")
# Out:
# True

# %%
download_web_page(url = "https://www.w3schools.com")
# Out:
# --2024-10-31 10:23:11--  https://www.w3schools.com/
# Resolving www.w3schools.com (www.w3schools.com)... 192.229.173.207
# Connecting to www.w3schools.com (www.w3schools.com)|192.229.173.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 390944 (382K) [text/html]
# Saving to: ‘./wget_web_page/www.w3schools.com/index.html’
#
#      0K .......... .......... .......... .......... .......... 13% 3.24M 0s
#     50K .......... .......... .......... .......... .......... 26% 44.7M 0s
#    100K .......... .......... .......... .......... .......... 39% 3.69M 0s
#    150K .......... .......... .......... .......... .......... 52%  116M 0s
#    200K .......... .......... .......... .......... .......... 65%  441M 0s
#    250K .......... .......... .......... .......... .......... 78% 3.79M 0s
#    300K .......... .......... .......... .......... .......... 91%  106M 0s
#    350K .......... .......... .......... .                    100%  380M=0.04s
#
# ...

# %%
webbrowser.open("wget_web_page/www.w3schools.com/index.html")
# Out:
# True
